# %%
import pandas as pd

# %%
RAW_DATA_FOLDER = "../data/raw"

cpi_set = pd.read_csv(f"{RAW_DATA_FOLDER}/ConsumerPriceIndex.csv")
trm_set = pd.read_csv(f"{RAW_DATA_FOLDER}/COP_TRM.csv")
gdp_set = pd.read_excel(f"{RAW_DATA_FOLDER}/GDP.xlsx")
occ_unem_set = pd.read_csv(f"{RAW_DATA_FOLDER}/OccupationAndUnemployement.csv")
policy_rate_set = pd.read_excel(f"{RAW_DATA_FOLDER}/policy_rate.xlsx")
colcap_set = pd.read_csv(f"{RAW_DATA_FOLDER}/stock_market_colcap.csv")

# %%
cpi_set.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1982 entries, 0 to 1981
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Fecha sistema              1982 non-null   str
#  1   Fecha (Mes año)            1982 non-null   str
#  2   Índice                     1982 non-null   float64
#  3   Variación mensual (%)      1969 non-null   float64
#  4   Variación anual (%)        1848 non-null   float64
#  5   Variación año corrido (%)  1969 non-null   float64
#  6   Orden_División             866 non-null    float64
#  7   División del gasto         1982 non-null   str
# dtypes: float64(5), str(3)
# memory usage: 124.0 KB

# %%
trm_set.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12705 entries, 0 to 12704
# Data columns (total 2 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Periodo(MMM DD, AAAA)                  12705 non-null  str
#  1   Tasa Representativa del Mercado (TRM)  12705 non-null  float64
# dtypes: float64(1), str(1)
# memory usage: 198.6 KB

# %%
gdp_set.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 2 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Fecha (dd/mm/aaaa/)                  82 non-null     str
#  1   Crecimiento PIB real trimestral (%)  82 non-null     str
# dtypes: str(2)
# memory usage: 1.4 KB

# %%
occ_unem_set.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Fecha sistema          716 non-null    str
#  1   Metodología            716 non-null    str
#  2   Cobertura geográfica   716 non-null    str
#  3   Fecha (Mes año)        716 non-null    str
#  4   Tasa de ocupación (%)  716 non-null    float64
#  5   Tasa de desempleo (%)  716 non-null    float64
# dtypes: float64(2), str(4)
# memory usage: 33.7 KB

# %%
policy_rate_set.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10023 entries, 0 to 10022
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Fecha (dd/mm/aaaa)              10023 non-null  datetime64[us]
#  1   Tasa de política monetaria (%)  10023 non-null  float64
# dtypes: datetime64[us](1), float64(1)
# memory usage: 156.7 KB

# %%
colcap_set.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4526 entries, 0 to 4525
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Fecha sistema         4526 non-null   str
#  1   Fecha (DD/MM/AAAA)    4526 non-null   str
#  2   Nombre del índice     4526 non-null   str
#  3   Índice                4526 non-null   float64
#  4   Variación absoluta    4526 non-null   float64
#  5   Variación porcentual  4526 non-null   float64
# dtypes: float64(3), str(3)
# memory usage: 212.3 KB
